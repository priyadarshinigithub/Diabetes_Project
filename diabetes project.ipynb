# %% [markdown]
# # Diabetic Project

# %% [markdown]
# This datasets consist of several medical predictor (independent) variables and one target (dependent) variable, Outcome. Independent variables include the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# # ##storing csv file to diabetes_data

# %%
diabetes_data= pd.read_csv("diabetes.csv")

# %%
diabetes_data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Describing the data

# %%
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### plotting a box plot for Insulin

# %%
diabetes_data.Insulin.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### plotting a  _***pie plot***_ for Glucose

# %%
diabetes_data.Glucose.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Glucose'>

# %% [markdown]
# ### plotting a _*bar plot*_ for Insulin

# %%
diabetes_data.Insulin.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### plotting a _**density plot**_ for outcome

# %%
diabetes_data.Outcome.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### the mean,mode,median values of Glucose,outcome

# %%
diabetes_data['Glucose'].mean()
# Out:
# 120.89453125

# %%
diabetes_data['Glucose'].mode()
# Out:
# 0     99
# 1    100
# dtype: int64

# %%
diabetes_data['Glucose'].median()
# Out:
# 117.0

# %%
diabetes_data['Outcome'].mean()
# Out:
# 0.3489583333333333

# %%
diabetes_data['Outcome'].mode()
# Out:
# 0    0
# dtype: int64

# %%
diabetes_data['Outcome'].median()
# Out:
# 0.0

# %% [markdown]
# ### scatter plot for Age & Glucose

# %%
sns.scatterplot(x='Age',y='Glucose',data=diabetes_data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Glucose'>

# %%
diabetes_data.Insulin.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
diabetes_data.skew()
# Out:
# Pregnancies                 0.901674
# Glucose                     0.173754
# BloodPressure              -1.843608
# SkinThickness               0.109372
# Insulin                     2.272251
# BMI                        -0.428982
# DiabetesPedigreeFunction    1.919911
# Age                         1.129597
# Outcome                     0.635017
# dtype: float64

# %%
diabetes_data.BloodPressure.plot(kind="density")
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ### the data of skewed variables

# %%
skewness=diabetes_data.skew()

# %%
skewness.sort_values()
# Out:
# BloodPressure              -1.843608
# BMI                        -0.428982
# SkinThickness               0.109372
# Glucose                     0.173754
# Outcome                     0.635017
# Pregnancies                 0.901674
# Age                         1.129597
# DiabetesPedigreeFunction    1.919911
# Insulin                     2.272251
# dtype: float64

# %% [markdown]
# ### Examine the outliers

# %%
diabetes_data.BloodPressure.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.SkinThickness.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.BMI.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.Glucose.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.Outcome.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.Pregnancies.plot(kind="box")
# Out:
# <AxesSubplot:>

# %%
diabetes_data.DiabetesPedigreeFunction.plot(kind="box")
# Out:
# <AxesSubplot:>

# %% [markdown]
# The outlyers for diabetes pedigree function are more when compare to the out comes
